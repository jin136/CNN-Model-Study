# %%
import tensorflow as tf
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential,Model,initializers,layers,Input
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"

# %%
def ResidualBlock_original(x,l):
    x1=x
    x1=layers.Conv2D(filters=l,kernel_size=(3,3),strides=(1,1),padding='same')(x1)
    x1=layers.BatchNormalization()(x1)
    x1=layers.ReLU()(x1)
    x1=layers.Conv2D(filters=l,kernel_size=(3,3),strides=(1,1),padding='same')(x1)
    x1=layers.BatchNormalization()(x1)
    x2=layers.Add()([x,x1])
    x2=layers.ReLU()(x2)

    return x2

# %%
def ResidualBlock_BN_after_addition(x,l):
    x1=x
    x1=layers.Conv2D(filters=l,kernel_size=(3,3),strides=(1,1),padding='same')(x1)
    x1=layers.BatchNormalization()(x1)
    x1=layers.ReLU()(x1)
    x1=layers.Conv2D(filters=l,kernel_size=(3,3),strides=(1,1),padding='same')(x1)
    x2=layers.Add()([x,x1])
    x2=layers.BatchNormalization()(x2)
    x2=layers.ReLU()(x2)

    return x2

# %%
def ResidualBlock_ReLU_before_addition(x,l):
    x1=x
    x1=layers.Conv2D(filters=l,kernel_size=(3,3),strides=(1,1),padding='same')(x1)
    x1=layers.BatchNormalization()(x1)
    x1=layers.ReLU()(x1)
    x1=layers.Conv2D(filters=l,kernel_size=(3,3),strides=(1,1),padding='same')(x1)
    x1=layers.BatchNormalization()(x1)
    x1=layers.ReLU()(x1)
    x2=layers.Add()([x,x1])

    return x2

# %%
def ResidualBlock_ReLU_only_pre_activation(x,l):
    x1=x
    x1=layers.Conv2D(filters=l,kernel_size=(3,3),strides=(1,1),padding='same')(x1)
    x1=layers.BatchNormalization()(x1)
    x1=layers.ReLU()(x1)
    x1=layers.Conv2D(filters=l,kernel_size=(3,3),strides=(1,1),padding='same')(x1)
    x1=layers.BatchNormalization()(x1)
    x2=layers.Add()([x,x1])

    return x2

# %%
def ResidualBlock_full_pre_activation(x,l):
    x1=x
    x1=layers.BatchNormalization()(x1)
    x1=layers.ReLU()(x1)
    x1=layers.Conv2D(filters=l,kernel_size=(3,3),strides=(1,1),padding='same')(x1)
    x1=layers.BatchNormalization()(x1)
    x1=layers.ReLU()(x1)
    x1=layers.Conv2D(filters=l,kernel_size=(3,3),strides=(1,1),padding='same')(x1)
    x2=layers.Add()([x,x1])
    
    return x2

# %%
inputs=Input(shape=(224,224,1))
x=layers.Conv2D(filters=64,kernel_size=(7,7),strides=(2,2),activation='relu',padding='same')(inputs)
x=layers.BatchNormalization()(x)
x=layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
x=ResidualBlock_full_pre_activation(x,64)
x=ResidualBlock_full_pre_activation(x,64)
x=ResidualBlock_full_pre_activation(x,64)

x=layers.Conv2D(filters=128,kernel_size=(3,3),strides=(2,2),padding='same')(x)
x=layers.BatchNormalization()(x)
x=layers.ReLU()(x)
x=layers.Conv2D(filters=128,kernel_size=(3,3),strides=(1,1),padding='same')(x)
x=layers.BatchNormalization()(x)
x=layers.ReLU()(x)

x=ResidualBlock_full_pre_activation(x,128)
x=ResidualBlock_full_pre_activation(x,128)
x=ResidualBlock_full_pre_activation(x,128)

x=layers.Conv2D(filters=256,kernel_size=(3,3),strides=(2,2),padding='same')(x)
x=layers.BatchNormalization()(x)
x=layers.ReLU()(x)
x=layers.Conv2D(filters=256,kernel_size=(3,3),strides=(1,1),padding='same')(x)
x=layers.BatchNormalization()(x)
x=layers.ReLU()(x)

x=ResidualBlock_full_pre_activation(x,256)
x=ResidualBlock_full_pre_activation(x,256)
x=ResidualBlock_full_pre_activation(x,256)
x=ResidualBlock_full_pre_activation(x,256)
x=ResidualBlock_full_pre_activation(x,256)

x=layers.Conv2D(filters=512,kernel_size=(3,3),strides=(2,2),padding='same')(x)
x=layers.BatchNormalization()(x)
x=layers.ReLU()(x)
x=layers.Conv2D(filters=512,kernel_size=(3,3),strides=(1,1),padding='same')(x)
x=layers.BatchNormalization()(x)
x=layers.ReLU()(x)

x=ResidualBlock_full_pre_activation(x,512)
x=ResidualBlock_full_pre_activation(x,256)

x=layers.GlobalAveragePooling2D()(x)
output=layers.Dense(units=10,activation='softmax')(x)
   
model = tf.keras.models.Model(inputs,output)

# %%
plot_model(model,to_file='ResNet_34.png',show_shapes=True)

# %%
(x_train,y_train),(x_test,y_test)=tf.keras.datasets.mnist.load_data()

# Normalization
x_train=x_train/255.

x_test=x_test/255.

#One-hot encoding
y_train = tf.keras.utils.to_categorical(np.array(y_train))
y_test = tf.keras.utils.to_categorical(np.array(y_test))


x_train = np.expand_dims(x_train, axis=-1)
x_train = tf.image.resize(x_train, [224,224])

x_test = np.expand_dims(x_test, axis=-1)
x_test = tf.image.resize(x_test, [224,224])

# %%
len(model.layers)
# Out:
# 115

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  3200        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  re_lu (ReLU)                   (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 64)   36928       ['re_lu[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 56, 56, 64)   0           ['max_pooling2d[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 56, 56, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 64)   36928       ['re_lu_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 56, 56, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 64)   36928       ['re_lu_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 56, 56, 64)   0           ['re_lu_1[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 56, 56, 64)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 64)   36928       ['re_lu_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 56, 56, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 64)   36928       ['re_lu_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['re_lu_3[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 56, 56, 64)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 128)  73856       ['re_lu_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 28, 28, 128)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 128)  147584      ['re_lu_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 28, 28, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  147584      ['re_lu_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 28, 28, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  147584      ['re_lu_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 28, 28, 128)  0           ['re_lu_7[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 28, 28, 128)  0           ['add_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 128)  147584      ['re_lu_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  147584      ['re_lu_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 28, 28, 128)  0           ['re_lu_9[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  re_lu_11 (ReLU)                (None, 28, 28, 128)  0           ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 128)  147584      ['re_lu_11[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 128)  147584      ['re_lu_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 28, 28, 128)  0           ['re_lu_11[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  re_lu_13 (ReLU)                (None, 28, 28, 128)  0           ['add_5[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 256)  295168      ['re_lu_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_15[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_16[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 14, 14, 256)  0           ['re_lu_15[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  re_lu_17 (ReLU)                (None, 14, 14, 256)  0           ['add_6[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_17[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_18[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 14, 14, 256)  0           ['re_lu_17[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  re_lu_19 (ReLU)                (None, 14, 14, 256)  0           ['add_7[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_19[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_20[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 14, 14, 256)  0           ['re_lu_19[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  re_lu_21 (ReLU)                (None, 14, 14, 256)  0           ['add_8[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_21[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_22[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 14, 14, 256)  0           ['re_lu_21[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  re_lu_23 (ReLU)                (None, 14, 14, 256)  0           ['add_9[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_23[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_24[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 14, 14, 256)  0           ['re_lu_23[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  re_lu_25 (ReLU)                (None, 14, 14, 256)  0           ['add_10[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 7, 7, 512)    1180160     ['re_lu_25[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_27[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 7, 7, 512)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 7, 7, 512)    2359808     ['re_lu_26[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_28[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 7, 7, 512)    0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 512)    2359808     ['re_lu_27[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_29[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 7, 7, 512)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 512)    2359808     ['re_lu_28[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_30[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 7, 7, 512)    0           ['re_lu_27[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  re_lu_29 (ReLU)                (None, 7, 7, 512)    0           ['add_11[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 512)    2359808     ['re_lu_29[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_31[0][0]']
#  ormalization)
#
#  re_lu_30 (ReLU)                (None, 7, 7, 512)    0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 512)    2359808     ['re_lu_30[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_32[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 7, 7, 512)    0           ['re_lu_29[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  re_lu_31 (ReLU)                (None, 7, 7, 512)    0           ['add_12[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['re_lu_31[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 10)           5130        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 21,132,554
# Trainable params: 21,117,322
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy' ,metrics=['acc'])

# %%
history=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=1,batch_size=8,verbose=1)
# Out:
# 7500/7500 [==============================] - 10613s 1s/step - loss: 0.1377 - acc: 0.9585 - val_loss: 0.0646 - val_acc: 0.9807
